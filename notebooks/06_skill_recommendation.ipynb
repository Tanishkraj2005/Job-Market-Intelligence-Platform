# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

# %%
from src.recommendation_engine import recommend_skills

# %%
import pandas as pd

df = pd.read_csv("D:/Skill Graph/data/processed/skill_matrix.csv")

df.head()
# Out:
#                                            Job Title  \
# 0  Data Analyst, Center on Immigration and Justic...
# 1                               Quality Data Analyst
# 2  Senior Data Analyst, Insights & Analytics Team...
# 3                                       Data Analyst
# 4                             Reporting Data Analyst
#
#               Salary Estimate  \
# 0  $37K-$66K (Glassdoor est.)
# 1  $37K-$66K (Glassdoor est.)
# 2  $37K-$66K (Glassdoor est.)
# 3  $37K-$66K (Glassdoor est.)
# 4  $37K-$66K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  are you eager to roll up your sleeves and harn...     3.2
# 1  overview\n\nprovides analytical and technical ...     3.8
# 2  we’re looking for a senior data analyst who ha...     3.4
# 3  requisition numberrr-0001939\nremote:yes\nwe c...     4.1
# 4  about fanduel group\n\nfanduel group is a worl...     3.9
#
#                               Company Name      Location  Headquarters  \
# ...

# %%
recommend_skills(
    "D:/Skill Graph/data/processed/skill_matrix.csv",
    ["excel", "sql"]
)
# Out:
# [('r', np.int64(2741)),
#  ('tableau', np.int64(938)),
#  ('python', np.int64(937)),
#  ('statistics', np.int64(836)),
#  ('data visualization', np.int64(507))]

# %%
rec = recommend_skills(
    "../data/processed/skill_matrix.csv",
    ["excel","sql"]
)

rec_df = pd.DataFrame(rec, columns=["Skill", "Score"])

rec_df
# Out:
#                 Skill  Score
# 0                   r   2741
# 1             tableau    938
# 2              python    937
# 3          statistics    836
# 4  data visualization    507

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8,5))

sns.barplot(
    x="Score",
    y="Skill",
    data=rec_df
)

plt.title("Recommended Skills for Excel + SQL")
plt.xlabel("Recommendation Score")
plt.ylabel("Skill")

plt.show()
